# %%
print('Hello, world!')
print('I am a Python string!')
print("Let's make a plot!")
print('How about the function f(x) = x^2?')

import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-4, 4.1, 0.1)
y = [z**2 for z in x]

plt.figure()
plt.plot(x, y)
plt.show()
# Out:
# Hello, world!
# I am a Python string!
# Let's make a plot!
# How about the function f(x) = x^2?
